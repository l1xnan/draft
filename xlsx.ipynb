# %%
import xlwings as xw
basepath = 'E:\\教务\\2016年下\\20160821-成绩数据分析\\'
app = xw.App(visible=False)

# %%
book = app.books.open(basepath + '2015-2016学年第二学期期期末考试登分表.xlsx')

# %%
sht = book.sheets[0]

# %%
rng = sht.range('A2').current_region

# %%
rng
# Out:
# <Range [2015-2016学年第二学期期期末考试登分表.xlsx]汇总!$A$1:$Q$306>

# %%
rng.last_cell
# Out:
# <Range [2015-2016学年第二学期期期末考试登分表.xlsx]汇总!$Q$306>

# %%
rng.rows[0]
# Out:
# <Range [2015-2016学年第二学期期期末考试登分表.xlsx]汇总!$A$1:$Q$1>

# %%
for row in rng.rows[1:]:
    print(row.value)
# Out:
# [1.0, '悉尼一班', '刘硕', 'Rock', '男', 98.0, 91.0, 95.0, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [2.0, '悉尼一班', '王晨博', 'Eli', '男', 95.5, 90.0, 99.0, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [3.0, '悉尼一班', '连勃尧', 'Lance', '男', 93.5, 98.5, 95.5, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [4.0, '悉尼一班', '王洵', 'Mark', '男', 99.5, 97.5, 100.0, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [5.0, '悉尼一班', '李嘉耀', 'Lee', '男', 93.0, 85.5, 93.5, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [6.0, '悉尼一班', '张庭纲', 'Kurt', '男', 96.0, 95.0, 100.0, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [7.0, '悉尼一班', '吉俊龙', 'Josh', '男', 95.5, 100.0, 96.5, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [8.0, '悉尼一班', '赵克强', 'Zack', '男', 98.0, 98.0, 96.0, None, None, None, None, None, '张会丽', '1年', '1班', None]
# [9.0, '悉尼一班', '王辰光', 'Edward', '男', 98.0, 94.0, 98.5, None, None, None, None, None, '张会丽', '1年', '1班', None]
# ...
